# %%
import random
cont= 0
secre=random.randint(1,100)
pal=0
while pal != secre :
 dica = input(" Dejesa ter dicas? ")
      if dica == "sim":
         pal = float(input("Palpite: "))
         if pal > secre:
           print("É menor")
         if 80 < pal <= 100:
           print("está perto")
         elif 60 < pal <= 80 and pal != 70:
           print("está muito perto")
         elif 40 < pal <= 60:
           print("está perto")
         elif 20 < pal <= 40:
           print("está longe")
         elif  pal <= 10:
           print("está muito longe")

      elif pal < secre:
        print("É maior")
        dif = secre-pal


      else:
        pal = float(input("Palpite: "))
        cont = cont+1

      if pal != secre:
       sair = input("Deseja sair? ")
       if sair == "sim":
             break
       else:
             pass

print("Você acertou!!!")
print("Tentativas: ",cont)
# Out:
#   File "<ipython-input-13-fe0794a2c51b>", line 7
#     if dica == "sim":
#     ^
# IndentationError: unexpected indent

# %%
qnt = int(input("Quantos itens são? "))
total= 0
for preco in range (qnt):
    preco = float(input("Preço do item: "))
    total = total+preco

vista = input("Vai ser a vista? ")
if vista == "sim":
    totalvista = total-(total*0.05)
    print("Total a ser pago: R$",totalvista)
elif vista == "não":
    print("Total a ser pago: R$",total)
else:
    print("Resposta invalida")
# Out:
# Quantos itens são? 2
# Preço do item: 40
# Preço do item: 60
# Vai ser a vista? não
# Total a ser pago: R$ 100.0
